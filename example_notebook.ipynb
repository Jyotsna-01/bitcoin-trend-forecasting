# %% [markdown]
# # Bitcoin Trend Forecasting - Example Walkthrough
#
# This notebook demonstrates the typical steps: fetch data, feature engineering, train LSTM/XGBoost, evaluate.

# %%
# Run the scripts in the repo. Example:
# !python data_fetch.py --start 2020-01-01 --end 2024-12-31 --out data/bitcoin_price.csv
# !python feature_engineer.py --in data/bitcoin_price.csv --out data/bitcoin_features.csv
# !python train_lstm.py --data data/bitcoin_features.csv --model_out models/lstm.pth
# !python train_xgboost.py --data data/bitcoin_features.csv --model_out models/xgb.pkl
